# %% [markdown]
# Exercício 1
# Crie um programa que mostre na tela:

# %%
print ("eu estou aprendendo ")
# Out:
# eu estou aprendendo

# %% [markdown]
# Exercício 2
# Crie um programa que mostre:

# %%
print("Meu nome é Maria e Eu moro em Recife")
# Out:
# Meu nome é Maria e Eu moro em Recife

# %%
nome = "maria"
cidade = " recife"
print ( " meu nome é ", nome , " E MORO E em ", cidade)
# Out:
#  meu nome é  maria  E MORO E em   recife

# %% [markdown]
# Exercício 4 (Desafio Extra)
# Crie três variáveis: cidade, estado e pais. E mostre:
# Eu moro em Salvador - BA, Brasil

# %%
nome = "patricia"
cidade = "Salvador"
estado = "Bahia"

print (" Meu nome é", nome , " more em ", cidade , estado, " Brasil " )
# Out:
#  Meu nome é patricia  more em  Salvador Bahia  Brasil

# %% [markdown]
# Crie um programa que:
# 1. Pergunte o nome do aluno.
# 2. Pergunte a cidade onde ele mora.
# 3. Mostre a frase:
#
# Olá João, você mora em Curitiba

# %%
entrada=input("digite seu nome")
entrada=input
